# %%
# !pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 76.5 MB/s eta 0:00:000m eta 0:00:01
# ...

# %%
# !pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 79.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.1/318.1 MB 45.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [xgboost]━━━ 1/2 [xgboost]
# ...

# %%
# !python -V
# Out:
# Python 3.12.1

# %%
import pandas as pd
import numpy as np

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge, RidgeCV

from sklearn.metrics import root_mean_squared_error

# %%
import xgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import xgb
#
# ModuleNotFoundError: No module named 'xgb'

# %%
df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 7             2  2021-01-01 00:26:31   2021-01-01 00:28:50                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
# ...

# %%
df.duration.describe()
# Out:
# count    73908.000000
# mean        16.852578
# std         11.563163
# min          1.000000
# 25%          8.050000
# 50%         14.000000
# 75%         22.633333
# max         60.000000
# Name: duration, dtype: float64

# %%
df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

# df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
df.duration.describe()
# Out:
# count    76518.000000
# mean        19.927896
# std         59.338594
# min          0.000000
# 25%          8.000000
# 50%         13.883333
# 75%         23.000000
# max       1439.600000
# Name: duration, dtype: float64

# %%
sns.distplot(df.duration)
# Out:
# /tmp/ipykernel_24833/3426635498.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.duration)
# <Axes: xlabel='duration', ylabel='Density'>

# %%
sns.histplot(df.duration, kde=True, binrange=[0,100], binwidth=1)
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
df.duration[df.duration<1].describe()
# Out:
# count    1448.000000
# mean        0.288409
# std         0.271799
# min         0.000000
# 25%         0.066667
# 50%         0.183333
# 75%         0.450000
# max         0.983333
# Name: duration, dtype: float64

# %%
sns.histplot(df.duration[df.duration<10], kde=True, binwidth=0.25)
#plt.xlim(0,100)
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %%
sns.histplot(df.duration[df.duration<1], kde=True, binwidth=0.1)
# Out:
# <Axes: xlabel='duration', ylabel='Count'>

# %%
что это, какие-то ошибки в данных?
можно ещё треки прочекать?

# %%
df[df.duration<1].sort_index()
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# 5             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# 6             2  2021-01-01 00:19:14   2021-01-01 00:19:21                  N
# 8             2  2021-01-01 00:57:46   2021-01-01 00:57:57                  N
# 15            2  2021-01-01 00:29:05   2021-01-01 00:29:07                  N
# ...         ...                  ...                   ...                ...
# 69341         2  2021-01-25 16:37:00   2021-01-25 16:37:00               None
# 71847         2  2021-01-27 12:58:00   2021-01-27 12:58:00               None
# 75879         2  2021-01-30 15:05:00   2021-01-30 15:05:00               None
# 75883         2  2021-01-30 16:34:00   2021-01-30 16:34:00               None
# 76086         2  2021-01-31 08:07:00   2021-01-31 08:07:00               None
#
# ...

# %%
df.store_and_fwd_flag.value_counts(dropna=False)
# Out:
# store_and_fwd_flag
# N       40205
# None    36047
# Y         266
# Name: count, dtype: int64

# %%
очень много None, если что

# %%
df.duration[df.store_and_fwd_flag.isna()]
# Out:
# 40471     5.0
# 40472    17.0
# 40473    20.0
# 40474    18.0
# 40475    23.0
#          ...
# 76513    38.0
# 76514    38.0
# 76515    11.0
# 76516    27.0
# 76517    10.0
# Name: duration, Length: 36047, dtype: float64

# %%
разные дурейшены, вообще есть для этих Нон, хз

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

root_mean_squared_error(y_train, y_pred)
# Out:
# 9.838799799829626

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# /tmp/ipykernel_24833/1672306066.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# /tmp/ipykernel_24833/1672306066.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
# %%time

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# CPU times: user 93.2 ms, sys: 773 μs, total: 94 ms
# Wall time: 69.4 ms
# 7.758715208009878

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_val, label='actual')

plt.legend()
# Out:
# /tmp/ipykernel_24833/2624495092.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# /tmp/ipykernel_24833/2624495092.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_val, label='actual')

# %%
sns.regplot(x=y_pred, y=y_val, marker='.', scatter_kws=dict(alpha=0.05))
# Out:
# <Axes: >

# %%
np.corrcoef(x=y_pred, y=y_val)[0,1]
# Out:
# np.float64(0.7795071152014048)

# %%
# %%time

lr = Ridge()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# CPU times: user 90.6 ms, sys: 1.87 ms, total: 92.4 ms
# Wall time: 71.1 ms
# 7.70373515548786

# %%
np.corrcoef(x=y_pred, y=y_val)[0,1]
# Out:
# np.float64(0.7879055731225412)

# %%
sns.regplot(x=y_pred, y=y_val, marker='.', scatter_kws=dict(alpha=0.05))
# Out:
# <Axes: >

# %%
# %%time

lr = Lasso()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# CPU times: user 2.54 s, sys: 1.03 ms, total: 2.54 s
# Wall time: 2.47 s
# 12.212583224318818

# %%
np.corrcoef(x=y_pred, y=y_val)[0,1]
# Out:
# np.float64(0.013514513072166704)

# %%
# %%time

import xgboost as xgb

# Create and train XGBoost model
xgb_model = xgb.XGBRegressor(
    # n_estimators=100,
    # learning_rate=0.1,
    random_state=42
)
xgb_model.fit(X_train, y_train)

# Make predictions
y_pred = xgb_model.predict(X_val)

# Calculate RMSE
root_mean_squared_error(y_val, y_pred)
# Out:
# CPU times: user 3.54 s, sys: 14.9 ms, total: 3.56 s
# Wall time: 2.06 s
# 6.644320289321216

# %%
np.corrcoef(x=y_pred, y=y_val)[0,1]
# Out:
# np.float64(0.8468467440522441)

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_val, label='actual')

plt.legend()
# Out:
# /tmp/ipykernel_24833/2624495092.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# /tmp/ipykernel_24833/2624495092.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_val, label='actual')

# %%
sns.regplot(x=y_pred, y=y_val, marker='.', scatter_kws=dict(alpha=0.05))
# Out:
# <Axes: >

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 with open('models/lin_reg.bin', 'wb') as f_out:
#       2     pickle.dump((dv, lr), f_out)
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/lin_reg.bin'

# %%
lr = Lasso(0.01)
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
# Out:
# 11.167275941179728

# %%
# %%time

lr = RidgeCV()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

root_mean_squared_error(y_val, y_pred)
